# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import warnings 
warnings.filterwarnings("ignore")

# %%
df1=pd.read_csv("bigdatamart_Train.csv")
df1
# Out:
#      Item_Identifier  Item_Weight Item_Fat_Content  Item_Visibility  \
# 0              FDA15        9.300          Low Fat         0.016047
# 1              DRC01        5.920          Regular         0.019278
# 2              FDN15       17.500          Low Fat         0.016760
# 3              FDX07       19.200          Regular         0.000000
# 4              NCD19        8.930          Low Fat         0.000000
# ...              ...          ...              ...              ...
# 8518           FDF22        6.865          Low Fat         0.056783
# 8519           FDS36        8.380          Regular         0.046982
# 8520           NCJ29       10.600          Low Fat         0.035186
# 8521           FDN46        7.210          Regular         0.145221
# 8522           DRG01       14.800          Low Fat         0.044878
#
#                   Item_Type  Item_MRP Outlet_Identifier  \
# 0                     Dairy  249.8092            OUT049
# ...

# %%
df2=pd.read_csv("bigdatamart_Test.csv")
df2
# Out:
#      Item_Identifier  Item_Weight Item_Fat_Content  Item_Visibility  \
# 0              FDW58       20.750          Low Fat         0.007565
# 1              FDW14        8.300              reg         0.038428
# 2              NCN55       14.600          Low Fat         0.099575
# 3              FDQ58        7.315          Low Fat         0.015388
# 4              FDY38          NaN          Regular         0.118599
# ...              ...          ...              ...              ...
# 5676           FDB58       10.500          Regular         0.013496
# 5677           FDD47        7.600          Regular         0.142991
# 5678           NCO17       10.000          Low Fat         0.073529
# 5679           FDJ26       15.300          Regular         0.000000
# 5680           FDU37        9.500          Regular         0.104720
#
#                Item_Type  Item_MRP Outlet_Identifier  \
# 0            Snack Foods  107.8622            OUT049
# ...

# %%
df1.columns
# Out:
# Index(['Item_Identifier', 'Item_Weight', 'Item_Fat_Content', 'Item_Visibility',
#        'Item_Type', 'Item_MRP', 'Outlet_Identifier',
#        'Outlet_Establishment_Year', 'Outlet_Size', 'Outlet_Location_Type',
#        'Outlet_Type', 'Item_Outlet_Sales'],
#       dtype='object')

# %%
df2.columns
# Out:
# Index(['Item_Identifier', 'Item_Weight', 'Item_Fat_Content', 'Item_Visibility',
#        'Item_Type', 'Item_MRP', 'Outlet_Identifier',
#        'Outlet_Establishment_Year', 'Outlet_Size', 'Outlet_Location_Type',
#        'Outlet_Type'],
#       dtype='object')

# %%
df1.shape
# Out:
# (8523, 12)

# %% [markdown]
# There are 8523 rows and 12 columns in the datasets

# %%
df2.shape
# Out:
# (5681, 11)

# %% [markdown]
# There are 5681 rows and 11 columns in the datasets

# %%
df1['source']='train'
df2['source']='test'

# %%
data = pd.concat([df1,df2], ignore_index = True)

# %%
data.shape
# Out:
# (14204, 13)

# %% [markdown]
# There are 14204 rows and 13 columns in the datasets

# %%
data
# Out:
#       Item_Identifier  Item_Weight Item_Fat_Content  Item_Visibility  \
# 0               FDA15         9.30          Low Fat         0.016047
# 1               DRC01         5.92          Regular         0.019278
# 2               FDN15        17.50          Low Fat         0.016760
# 3               FDX07        19.20          Regular         0.000000
# 4               NCD19         8.93          Low Fat         0.000000
# ...               ...          ...              ...              ...
# 14199           FDB58        10.50          Regular         0.013496
# 14200           FDD47         7.60          Regular         0.142991
# 14201           NCO17        10.00          Low Fat         0.073529
# 14202           FDJ26        15.30          Regular         0.000000
# 14203           FDU37         9.50          Regular         0.104720
#
#                    Item_Type  Item_MRP Outlet_Identifier  \
# 0                      Dairy  249.8092            OUT049
# ...

# %%
data.columns
# Out:
# Index(['Item_Identifier', 'Item_Weight', 'Item_Fat_Content', 'Item_Visibility',
#        'Item_Type', 'Item_MRP', 'Outlet_Identifier',
#        'Outlet_Establishment_Year', 'Outlet_Size', 'Outlet_Location_Type',
#        'Outlet_Type', 'Item_Outlet_Sales', 'source'],
#       dtype='object')

# %%
data.dtypes
# Out:
# Item_Identifier               object
# Item_Weight                  float64
# Item_Fat_Content              object
# Item_Visibility              float64
# Item_Type                     object
# Item_MRP                     float64
# Outlet_Identifier             object
# Outlet_Establishment_Year      int64
# Outlet_Size                   object
# Outlet_Location_Type          object
# Outlet_Type                   object
# Item_Outlet_Sales            float64
# source                        object
# dtype: object

# %% [markdown]
# There are float and categorical values in the column .We need to use Encoder to change it to numerical type

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 14204 entries, 0 to 14203
# Data columns (total 13 columns):
#  #   Column                     Non-Null Count  Dtype
# ---  ------                     --------------  -----
#  0   Item_Identifier            14204 non-null  object
#  1   Item_Weight                11765 non-null  float64
#  2   Item_Fat_Content           14204 non-null  object
#  3   Item_Visibility            14204 non-null  float64
#  4   Item_Type                  14204 non-null  object
#  5   Item_MRP                   14204 non-null  float64
#  6   Outlet_Identifier          14204 non-null  object
#  7   Outlet_Establishment_Year  14204 non-null  int64
#  8   Outlet_Size                10188 non-null  object
#  9   Outlet_Location_Type       14204 non-null  object
#  10  Outlet_Type                14204 non-null  object
#  11  Item_Outlet_Sales          8523 non-null   float64
#  12  source                     14204 non-null  object
# ...

# %% [markdown]
# There are null values present in our dataset we need to fix it.Here memory usage: 1.4+ MB

# %%
data.describe()
# Out:
#         Item_Weight  Item_Visibility      Item_MRP  Outlet_Establishment_Year  \
# count  11765.000000     14204.000000  14204.000000               14204.000000
# mean      12.792854         0.065953    141.004977                1997.830681
# std        4.652502         0.051459     62.086938                   8.371664
# min        4.555000         0.000000     31.290000                1985.000000
# 25%        8.710000         0.027036     94.012000                1987.000000
# 50%       12.600000         0.054021    142.247000                1999.000000
# 75%       16.750000         0.094037    185.855600                2004.000000
# max       21.350000         0.328391    266.888400                2009.000000
#
#        Item_Outlet_Sales
# count        8523.000000
# mean         2181.288914
# std          1706.499616
# min            33.290000
# 25%           834.247400
# 50%          1794.331000
# 75%          3101.296400
# max         13086.964800

# %% [markdown]
# Describe gives the statistical values of the dataset.Here we can see 3rd quartile value is greater than mean values.Hence,it will give good model

# %%
data.isnull().sum()
# Out:
# Item_Identifier                 0
# Item_Weight                  2439
# Item_Fat_Content                0
# Item_Visibility                 0
# Item_Type                       0
# Item_MRP                        0
# Outlet_Identifier               0
# Outlet_Establishment_Year       0
# Outlet_Size                  4016
# Outlet_Location_Type            0
# Outlet_Type                     0
# Item_Outlet_Sales            5681
# source                          0
# dtype: int64

# %% [markdown]
# Here we null values in Item_Weight =2439
#                        Outlet_Type =4016
#                        Item_Outlet_Sales=5681

# %%
sns.heatmap(data.isnull())
# Out:
# <AxesSubplot:>

# %% [markdown]
# Usng heatmap also we can check null value.Here we have null value present.So,we need to resolve

# %%
data['Item_Outlet_Sales'].unique()
# Out:
# array([3735.138 ,  443.4228, 2097.27  , ..., 3608.636 , 2778.3834,
#              nan])

# %%
print(data['Item_Outlet_Sales'].value_counts())
# Out:
# 958.7520     17
# 1342.2528    16
# 1845.5976    15
# 703.0848     15
# 1230.3984    14
#              ..
# 1883.5482     1
# 5386.9878     1
# 4231.8248     1
# 91.2146       1
# 3653.9104     1
# Name: Item_Outlet_Sales, Length: 3493, dtype: int64

# %% [markdown]
# # EDA

# %%
sns.countplot(data['Item_Outlet_Sales'])
# Out:
# <AxesSubplot:xlabel='Item_Outlet_Sales', ylabel='count'>

# %%
sns.distplot(data["Item_Outlet_Sales"])
# Out:
# <AxesSubplot:xlabel='Item_Outlet_Sales', ylabel='Density'>

# %% [markdown]
# It is Left distributed .It is having skewness

# %%
sns.distplot(data['Item_Weight'])
# Out:
# <AxesSubplot:xlabel='Item_Weight', ylabel='Density'>

# %% [markdown]
# It is not normally distributed .It is having skewness

# %%
sns.distplot(data['Item_Visibility'])
# Out:
# <AxesSubplot:xlabel='Item_Visibility', ylabel='Density'>

# %% [markdown]
# It is Left distributed .It is having skewness

# %%
sns.distplot(data['Item_MRP'])
# Out:
# <AxesSubplot:xlabel='Item_MRP', ylabel='Density'>

# %% [markdown]
# It is not normally distributed .It is having skewness

# %%
for i in data.describe().columns:
    sns.boxplot(data[i])
    plt.show()

# %% [markdown]
# here we can see we have outliers present in Item_weight and Item_Outlet_Sales

# %%
sns.countplot(data['Outlet_Establishment_Year'])
# Out:
# <AxesSubplot:xlabel='Outlet_Establishment_Year', ylabel='count'>

# %% [markdown]
# year 1985 have highest count and 1998 have the list

# %%
sns.countplot(data['Item_Fat_Content'])
# Out:
# <AxesSubplot:xlabel='Item_Fat_Content', ylabel='count'>

# %% [markdown]
# low fat have more count

# %%
sns.pairplot(data,hue="Item_Outlet_Sales")

# %% [markdown]
# Pairplot shows the outliers and skewness of target and feature column.We observed that many values are scattered.

# %%
ax=sns.stripplot(x="Item_Type",y="Item_Outlet_Sales",data=data)
plt.title("graph")
plt.show()

# %% [markdown]
# Here we can see 4 value in the graph is more scatter than comparing to other column values

# %%
#Set up a category plot
g=sns.catplot(x="Item_Type",y="Item_Outlet_Sales",data=data,kind="violin")
#show plot
plt.show()

# %% [markdown]
# Using violin plot also we can check one indepented value with the comparsion with target value

# %%
#Set up a category plot
g=sns.catplot(x="Item_Type",y="Item_Outlet_Sales",data=data,kind="bar",height=20)
#show plot
plt.show()

# %% [markdown]
# here we can see seafood is getting more higher than other values

# %%
sns.boxplot(x="Item_Type",y="Item_Outlet_Sales",data=data,palette="coolwarm")
# Out:
# <AxesSubplot:xlabel='Item_Type', ylabel='Item_Outlet_Sales'>

# %% [markdown]
# we can expect sea food all r having skewness issue

# %%
from sklearn.preprocessing import LabelEncoder

# %%
encoder = LabelEncoder()
data['Item_Identifier'] = encoder.fit_transform(data['Item_Identifier'])
data['Item_Fat_Content'] = encoder.fit_transform(data['Item_Fat_Content'])
data['Item_Type'] = encoder.fit_transform(data['Item_Type'])
data['Outlet_Identifier'] = encoder.fit_transform(data['Outlet_Identifier'])
data['Outlet_Size'] = encoder.fit_transform(data['Outlet_Size'])
data['Outlet_Location_Type'] = encoder.fit_transform(data['Outlet_Location_Type'])
data['Outlet_Type'] = encoder.fit_transform(data['Outlet_Type'])

# %%
data.head()
# Out:
#    Item_Identifier  Item_Weight  Item_Fat_Content  Item_Visibility  Item_Type  \
# 0              156         9.30                 1         0.016047          4
# 1                8         5.92                 2         0.019278         14
# 2              662        17.50                 1         0.016760         10
# 3             1121        19.20                 2         0.000000          6
# 4             1297         8.93                 1         0.000000          9
#
#    Item_MRP  Outlet_Identifier  Outlet_Establishment_Year  Outlet_Size  \
# 0  249.8092                  9                       1999            1
# 1   48.2692                  3                       2009            1
# 2  141.6180                  9                       1999            1
# 3  182.0950                  0                       1998            3
# 4   53.8614                  1                       1987            0
#
#    Outlet_Location_Type  Outlet_Type  Item_Outlet_Sales source
# ...

# %% [markdown]
# # Treating missing values

# %%
data.isnull().sum()
# Out:
# Item_Identifier                 0
# Item_Weight                  2439
# Item_Fat_Content                0
# Item_Visibility                 0
# Item_Type                       0
# Item_MRP                        0
# Outlet_Identifier               0
# Outlet_Establishment_Year       0
# Outlet_Size                     0
# Outlet_Location_Type            0
# Outlet_Type                     0
# Item_Outlet_Sales            5681
# source                          0
# dtype: int64

# %% [markdown]
# So here we can see we have missing values in  Item_Weight and Item_Outlet_Sales

# %%
data['Item_Weight']=data['Item_Weight'].fillna(data['Item_Weight'].mean())
data['Item_Weight'].isnull().sum()
# Out:
# 0

# %%
data.isnull().sum()
# Out:
# Item_Identifier                 0
# Item_Weight                     0
# Item_Fat_Content                0
# Item_Visibility                 0
# Item_Type                       0
# Item_MRP                        0
# Outlet_Identifier               0
# Outlet_Establishment_Year       0
# Outlet_Size                     0
# Outlet_Location_Type            0
# Outlet_Type                     0
# Item_Outlet_Sales            5681
# source                          0
# dtype: int64

# %%
from sklearn.preprocessing import LabelEncoder
le=LabelEncoder()
df=data.apply(LabelEncoder().fit_transform)
df
# Out:
#        Item_Identifier  Item_Weight  Item_Fat_Content  Item_Visibility  \
# 0                  156          284                 1             1097
# 1                    8           57                 2             1436
# 2                  662          376                 1             1172
# 3                 1121          393                 2                0
# 4                 1297          265                 1                0
# ...                ...          ...               ...              ...
# 14199              233          298                 2              718
# 14200              308          180                 2            11820
# 14201             1426          293                 1             8009
# 14202              521          354                 2                0
# 14203              997          288                 2            10187
#
#        Item_Type  Item_MRP  Outlet_Identifier  Outlet_Establishment_Year  \
# ...

# %%
df.isnull().sum()
# Out:
# Item_Identifier              0
# Item_Weight                  0
# Item_Fat_Content             0
# Item_Visibility              0
# Item_Type                    0
# Item_MRP                     0
# Outlet_Identifier            0
# Outlet_Establishment_Year    0
# Outlet_Size                  0
# Outlet_Location_Type         0
# Outlet_Type                  0
# Item_Outlet_Sales            0
# source                       0
# dtype: int64

# %% [markdown]
# now we can see values are not having any missing values

# %%
cor=df.corr()
cor
# Out:
#                            Item_Identifier  Item_Weight  Item_Fat_Content  \
# Item_Identifier                   1.000000     0.027238         -0.096220
# Item_Weight                       0.027238     1.000000         -0.024527
# Item_Fat_Content                 -0.096220    -0.024527          1.000000
# Item_Visibility                  -0.045484    -0.003890          0.038220
# Item_Type                        -0.012048     0.036341         -0.121140
# Item_MRP                          0.012340     0.024470         -0.006551
# Outlet_Identifier                -0.001089     0.002194         -0.001733
# Outlet_Establishment_Year        -0.003173    -0.079270         -0.002541
# Outlet_Size                       0.002786    -0.024476         -0.004608
# Outlet_Location_Type             -0.002473     0.009454         -0.002518
# Outlet_Type                      -0.004532     0.054561         -0.002380
# Item_Outlet_Sales                 0.003767    -0.006861          0.003605
# ...

# %% [markdown]
# we can see that many values are betwwen -0.5 to +0.5.so we can see somwhat it is correlated

# %%
plt.figure(figsize=[22,12])
sns.heatmap(cor,annot=True)
plt.title("Correlation Matrix")
plt.show()

# %% [markdown]
# here we can only 47% is corrleated which is Outlet_Location type with Outlet_type

# %%
plt.figure(figsize=(22,7))
df.corr()['Item_Outlet_Sales'].sort_values(ascending=False).drop(['Item_Outlet_Sales']).plot(kind='bar',color='c')
plt.xlabel('Feature',fontsize=14)
plt.ylabel('column with target names',fontsize=14)
plt.title('correlation',fontsize=18)
plt.show()

# %% [markdown]
# Here we can see item_mrp,outle_type,outlet_identifier is positve skewness,after that values is keep desreasin dramactically to negative correlation

# %% [markdown]
# # Outlier removing

# %%
from scipy.stats import zscore
z=np.abs(zscore(df))
new_df=df[(z<3).all(axis=1)]
new_df
# Out:
#        Item_Identifier  Item_Weight  Item_Fat_Content  Item_Visibility  \
# 0                  156          284                 1             1097
# 1                    8           57                 2             1436
# 2                  662          376                 1             1172
# 3                 1121          393                 2                0
# 4                 1297          265                 1                0
# ...                ...          ...               ...              ...
# 14199              233          298                 2              718
# 14200              308          180                 2            11820
# 14201             1426          293                 1             8009
# 14202              521          354                 2                0
# 14203              997          288                 2            10187
#
#        Item_Type  Item_MRP  Outlet_Identifier  Outlet_Establishment_Year  \
# ...

# %%
new_df.skew()
# Out:
# Item_Identifier             -0.005751
# Item_Weight                 -1.396898
# Item_Fat_Content             0.278518
# Item_Visibility              0.020637
# Item_Type                    0.091959
# Item_MRP                     0.023993
# Outlet_Identifier           -0.061063
# Outlet_Establishment_Year    0.036093
# Outlet_Size                 -0.131818
# Outlet_Location_Type        -0.210582
# Outlet_Type                  0.923905
# Item_Outlet_Sales           -0.410950
# source                      -0.407865
# dtype: float64

# %% [markdown]
# here we can see approx values are between -0.5 to +0.5.So,we can say almost skewness is resolved

# %%
new_df.shape
# Out:
# (13944, 13)

# %%
df.shape
# Out:
# (14204, 13)

# %%
13944/14204
# Out:
# 0.9816952970994086

# %% [markdown]
# so we can say that 0% data is lost.So we can use the new df value for building our model

# %%
x=new_df.drop("Item_Outlet_Sales",axis=1)
y=new_df["Item_Outlet_Sales"]

# %%
from sklearn.preprocessing import StandardScaler
SC=StandardScaler()
x=SC.fit_transform(x)
x
# Out:
# array([[-1.38700212, -0.15498087, -0.58489496, ..., -1.37040036,
#         -0.25357913,  0.81666738],
#        [-1.71511182, -2.56291653,  1.17737283, ...,  1.09065478,
#          0.99806951,  0.81666738],
#        [-0.26522166,  0.82092256, -0.58489496, ..., -1.37040036,
#         -0.25357913,  0.81666738],
#        ...,
#        [ 1.42853382, -0.05951206, -0.58489496, ..., -0.13987279,
#         -0.25357913, -1.22448873],
#        [-0.57781266,  0.58755435,  1.17737283, ..., -0.13987279,
#         -0.25357913, -1.22448873],
#        [ 0.47745908, -0.11255029,  1.17737283, ..., -0.13987279,
#         -0.25357913, -1.22448873]])

# %%
from sklearn.metrics import accuracy_score
from sklearn.metrics import confusion_matrix, classification_report
from sklearn.model_selection import train_test_split
from sklearn.model_selection import cross_val_score
from sklearn.model_selection import GridSearchCV
from sklearn.linear_model import LinearRegression, Ridge, Lasso
from sklearn.ensemble import RandomForestRegressor
from sklearn.svm import SVR
from sklearn.metrics import r2_score,mean_squared_error

# %%
x_train, x_test, y_train, y_test = train_test_split(x,y, test_size = 0.20, random_state=140)

# %%
#Linear Regression:
lr = LinearRegression()
lr.fit(x_train,y_train)
predlr = lr.predict(x_test)
print(r2_score(y_test,predlr))
print(mean_squared_error(y_test,predlr))
print(np.sqrt(mean_squared_error(y_test,predlr)))
scr = cross_val_score(lr,x,y,cv=5)
print('Cross validation score for Linear Regression Model is ',scr.mean()*100)
# Out:
# 0.7594868671913952
# 346023.1403686068
# 588.2373163686632
# Cross validation score for Linear Regression Model is  24.33764388924046

# %%
#Ridge Regression:
r = Ridge()
r.fit(x_train,y_train)
predr = r.predict(x_test)
print(r2_score(y_test,predr))
print(mean_squared_error(y_test,predr))
print(np.sqrt(mean_squared_error(y_test,predr)))
scr = cross_val_score(r,x,y,cv=5)
print('Cross validation score for Ridge Regression Model is', scr.mean()*100)
# Out:
# 0.7594861473378821
# 346024.17601256643
# 588.238196662344
# Cross validation score for Ridge Regression Model is 24.33626446386193

# %%
#Lasso Regression :

l = Lasso()
l.fit(x_train,y_train)
predl = l.predict(x_test)
print(r2_score(y_test,predl))
print(mean_squared_error(y_test,predl))
print(np.sqrt(mean_squared_error(y_test,predl)))
scr = cross_val_score(l,x,y,cv=5)
print('Cross validation score for Lasso Regression Model is ', scr.mean()*100)
# Out:
# 0.7595214497699991
# 345973.38685905485
# 588.1950245106251
# Cross validation score for Lasso Regression Model is  24.253332886938132

# %%
#Random Forest::

rf = RandomForestRegressor()
rf.fit(x_train,y_train)
predrf = rf.predict(x_test)
print(r2_score(y_test,predrf))
print(mean_squared_error(y_test,predrf))
print(np.sqrt(mean_squared_error(y_test,predrf)))
scr = cross_val_score(rf,x,y,cv=5)
print('Cross validation score for Random Forest Regressor Model is', scr.mean()*100)
# Out:
# 0.865771619703869
# 193112.63852531373
# 439.4458311616049
# Cross validation score for Random Forest Regressor Model is 77.19432268105739

# %%
best_model=pd.DataFrame({'Model':['Linear Regression','Ridge Regression','Lasso Regression','RandomForestRegressor'],
                         'R_2 score':[75.94,75.94,75.95,86.57],
                         'Cross_validation':[24.33,24.33,24.25,77.19]})
best_model
# Out:
#                    Model  R_2 score  Cross_validation
# 0      Linear Regression      75.94             24.33
# 1       Ridge Regression      75.94             24.33
# 2       Lasso Regression      75.95             24.25
# 3  RandomForestRegressor      86.57             77.19

# %% [markdown]
# Here we can see only RandomForestRegressor is having least difference so we can choose it for our best model.But for that we can check GRID SEARCH CV also

# %%
parameters1 = {'alpha': [4.0, 5.0, 6.0, 7.0, 8.0, 10.0],
             'random_state': [200, 700, 900],
             'max_iter': [200, 900],
             'solver': ['auto', 'svd', 'cholesky', 'lsqr', 'sparse_cg', 'sag', 'saga']}
GCV=GridSearchCV(Ridge(),parameters1,cv=5)
GCV.fit(x_train,y_train)
# Out:
# GridSearchCV(cv=5, estimator=Ridge(),
#              param_grid={'alpha': [4.0, 5.0, 6.0, 7.0, 8.0, 10.0],
#                          'max_iter': [200, 900],
#                          'random_state': [200, 700, 900],
#                          'solver': ['auto', 'svd', 'cholesky', 'lsqr',
#                                     'sparse_cg', 'sag', 'saga']})

# %%
GCV.best_params_
# Out:
# {'alpha': 8.0, 'max_iter': 200, 'random_state': 200, 'solver': 'sag'}

# %%
model=Ridge(alpha=8.0,random_state=200,solver='sag',max_iter=200)
model.fit(x_train,y_train)
pred=model.predict(x_test)
print(r2_score(y_test,predrf)*100)
print(mean_squared_error(y_test,predrf))
print(np.sqrt(mean_squared_error(y_test,predrf)))
# Out:
# 86.5771619703869
# 193112.63852531373
# 439.4458311616049

# %% [markdown]
# Hence pur model is 86% accurate.

# %%
import joblib
joblib.dump(rf,"Final_Big_Data_Mart_Sales.pkl")
# Out:
# ['Final_Big_Data_Mart_Sales.pkl']

# %% [markdown]
# # Saving ur best Model at the end
